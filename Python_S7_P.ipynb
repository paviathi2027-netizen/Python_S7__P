# %%
d1 = {
    1:"Yogita",2:"Prakash",3:"Jiju",4:"Akshit"
}

# %%
d1
# Out:
# {1: 'Yogita', 2: 'Prakash', 3: 'Jiju', 4: 'Akshit'}

# %%
d1[1]
# Out:
# 'Yogita'

# %%
d1.keys()
# Out:
# dict_values(['Yogita', 'Prakash', 'Jiju', 'Akshit'])

# %%
d1.values()
# Out:
# dict_values(['Yogita', 'Prakash', 'Jiju', 'Akshit'])

# %%
d1.items()
# Out:
# dict_items([(1, 'Yogita'), (2, 'Prakash'), (3, 'Jiju'), (4, 'Akshit')])

# %%
for k,v in d1.items():
  print("key:", k ,"value:", v)
# Out:
# key: 1 value: Yogita
# key: 2 value: Prakash
# key: 3 value: Jiju
# key: 4 value: Akshit

# %%
d2={"Roll No": [1,2,3,4], "Names": ["Yogita","Prakash","Jiju","Akshit"]}

# %%
d2
# Out:
# {'Roll No': [1, 2, 3, 4], 'Names': ['Yogita', 'Prakash', 'Jiju', 'Akshit']}

# %%
d1.update({5:"Adharsh"})
d1
# Out:
# {1: 'Yogita', 2: 'Prakash', 3: 'Jiju', 4: 'Akshit', 5: 'Adharsh'}

# %%
d1.pop(5)
# Out:
# 'Adharsh'

# %%
d1
# Out:
# {1: 'Yogita', 2: 'Prakash', 3: 'Jiju', 4: 'Akshit'}

# %%
# Employee Directory Management System
# Commplete the code as per the instrictions provided in the comments

# Initialize an empty dictionary to store employee records
employee_directory = {}

# %%
employee_directory.update({"employee_id":[1,2,3,4,5],"name":["Vijay","Ram","Sonu","Akshaya","vinod"],"department":["HR","IT","IT","HR","HR"]})

# %%
employee_directory
# Out:
# {'employee_id': [1, 2, 3, 4, 5],
#  'name': ['Vijay', 'Ram', 'Sonu', 'Akshaya', 'vinod'],
#  'department': ['HR', 'IT', 'IT', 'HR', 'HR']}

# %%
# Function to add a new employee
def add_employee(employee_id, name, department):
    if employee_id not in employee_directory:
        #1 Add the new employee record to the dictionary

        print(f"Employee {name} added successfully.")
    else:
        print(f"Employee ID {employee_id} already exists.")

# %%
add_employee(6,"Vishal","IT")
# Out:
# Employee Vishal added successfully.

# %%
add_employee(7,"Arun","HR")
# Out:
# Employee Arun added successfully.

# %%
print(employee_directory)
# Out:
# {'employee_id': [1, 2, 3, 4, 5], 'name': ['Vijay', 'Ram', 'Sonu', 'Akshaya', 'vinod'], 'department': ['HR', 'IT', 'IT', 'HR', 'HR']}

# %%
# Function to retrieve employee details
def get_employee(employee_id):
    #2 Use the appropriate dictionary method in place of None to retrieve the employee record
    employee = None
    if employee:
        return employee
    else:
        return "Employee not found."

# %%
get_employee(1)
# Out:
# 'Employee not found.'

# %%
# Function to update employee department
def update_employee(employee_id, new_department):
    if employee_id in employee_directory:
        #3 Update the employee record with the new department in the dictionary

        print(f"Employee ID {employee_id}'s department updated to {new_department}.")
    else:
        print("Employee not found.")

# %%
# Function to remove and return the employee
def remove_employee(employee_id):
    #4 return the removed employee record from the dictionary
    pass

# Function to display the entire employee directory
def display_directory():
    if employee_directory:
        print("\nEmployee Directory:")
       #5 Display the employee records in the dictionary using a loop and appropriate dictionary method
       # that retrieves the key-value pairs in the dictionary.
    else:
        print("The employee directory is empty.")

# Sample usage
if __name__ == "__main__":
    # Adding employees
    add_employee(101, "Alice Johnson", "HR")
    add_employee(102, "Bob Smith", "Engineering")
    add_employee(103, "Charlie Brown", "Marketing")

    # Displaying the directory
    display_directory()

    # Retrieving employee details
    print(get_employee(102))  # Should return details for Bob Smith

    # Updating employee department
    update_employee(103, "Sales")

    # Displaying the directory again
    display_directory()

    # Removing an employee
    print("Removed employee:", remove_employee(101))

    # Displaying the directory again
    display_directory()
# Out:
# Employee Alice Johnson added successfully.
# Employee Bob Smith added successfully.
# Employee Charlie Brown added successfully.
#
# Employee Directory:
# Employee not found.
# Employee not found.
#
# Employee Directory:
# Removed employee: None
#
# Employee Directory:

# %%
for i in range(100):
  print(i * i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801

# %%
sqrt_dict = {x : x ** 2 for x in range(1,6)}  #Key-Value pair(x :x) in 'Dict'
print(sqrt_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sqrt_set = { x ** 2 for x in range(1,6)} #Only values(x) in 'Set'
print(sqrt_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
my_dict = {'name':'Jhon','age':30}
print(my_dict.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
print(my_dict.values())
# Out:
# dict_values(['Jhon', 30])

# %%
fruits = {"apple":10,"banana":20,"cherry":15}
last_item = fruits.popitem()   #popitem() method returns the last item
print(last_item)
print(fruits)
# Out:
# ('cherry', 15)
# {'apple': 10, 'banana': 20}

# %%
inventory = {"item1":5,"item2":8}
inventory.clear()   #clean() method delete all
print(inventory)
# Out:
# {}

# %%
my_list = [1,2,3]
index=1
if index < len(my_list):
  print(my_list[index])
else:
  print("Index out of range")
# Out:
# 2

# %%
my_dict = {"name":"Alice"}
if "age" in my_dict:
  print(my_dict["age"])
else:
  print("Key not found")
# Out:
# Key not found

# %%
                #OR
print(my_dict.get("age","key not found"))
# Out:
# key not found

# %%
my_tuple = (1,2,3)    #Tuple is "Immutable" so tuple -> list-> modify
                                  # After modification modify-> list ->tuple
#convert the tuple to list to modify
my_list = list(my_tuple)
my_list[0] = 10 #modify the first element
# convet list to tuple
my_tuple = tuple(my_list)
print(my_tuple)
# Out:
# (10, 2, 3)

# %%
my_set = {1,2,3}
my_set.add(4)  #add element
for item in my_set:
  print(item)
# Out:
# 1
# 2
# 3
# 4
